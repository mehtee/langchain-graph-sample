# %%
from simple_graph_builder import (
    GraphConfig,
    CIMConfig,
    RelatedMetadataConfig,
    FewShotConfig,
    SplDocsConfig,
    GenerateConfig,
    SyntaxCheckConfig,
    ExecuteConfig,
    ReflectConfig,
    get_graph
)
from IPython.display import display, Image
from langchain_core.runnables.graph import MermaidDrawMethod

# %%
config = GraphConfig(
    execute=ExecuteConfig(),
)
g = get_graph(config).compile()
display(
    Image(
        g.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
config = GraphConfig(syntax_check=SyntaxCheckConfig())
g = get_graph(config).compile()
display(
    Image(
        g.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
config = GraphConfig(
    syntax_check=SyntaxCheckConfig(),
    execute=ExecuteConfig(),
)
g = get_graph(config).compile()
display(
    Image(
        g.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
config = GraphConfig(
    syntax_check=SyntaxCheckConfig(),
    execute=ExecuteConfig(),
    reflect=ReflectConfig(),
)
g = get_graph(config).compile()
display(
    Image(
        g.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
config = GraphConfig()
g = get_graph(config).compile()
display(
    Image(
        g.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
config = GraphConfig(
    cim=CIMConfig(),
)
g = get_graph(config).compile()
display(
    Image(
        g.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
 config = GraphConfig(
    cim=CIMConfig(),
    related_metadata=RelatedMetadataConfig(),
    few_shot=FewShotConfig(),
    spl_docs=SplDocsConfig(),
)
g = get_graph(config).compile()
display(
    Image(
        g.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
config = GraphConfig(
    cim=CIMConfig(),
    related_metadata=RelatedMetadataConfig(),
    few_shot=FewShotConfig(),
    spl_docs=SplDocsConfig(),
    syntax_check=SyntaxCheckConfig(),
    execute=ExecuteConfig(),
    reflect=ReflectConfig(),
)
g = get_graph(config).compile()
display(
    Image(
        g.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)
